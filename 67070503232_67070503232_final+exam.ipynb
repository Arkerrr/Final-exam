# %% [markdown]
# **REMINDER: SAVE AS your notebook in Deskstop with name "StudentID_final exam.ipynb"**

# %% [markdown]
# **Question 1** - **25  marks**
#
#
# A construction site keeps daily records of concrete truck deliveries. Each record contains the truck ID and the delivered volume (in cubic meters).
#
# You are given the following list of delivery records:
#
# deliveries = [
#     ("T01", 5.5),
#     ("T02", 7.0),
#     ("T01", 4.5),
#     ("T03", 6.0),
#     ("T02", 5.0),
# ]
#
# **(a) Write a function to compute total volumes — 12 marks**
#
# Create a function named total_volume(deliveries).
#
# The function must:
#
#
# *   take the list of deliveries as an input parameter.
# *   create an empty dictionary to store total volumes for each truck.
# *   loop through each tuple in the list.
# *   add the delivered volume to the correct truck ID inside the dictionary.
#
#
# The function must return a dictionary in the following format:
#
# {
#
#     "T01": total volume delivered by T01,
#
#     "T02": total volume delivered by T02,
#
#     "T03": total volume delivered by T03
# }
#
# Example of expected output (your program must calculate it):
# {
#     "T01": 10.0,
#
#     "T02": 12.0,
#
#     "T03": 6.0
# }

# %%
class deliveries:
    def __init__(self,truck, volume):
        self.truck = truck
        self.volume = volume
    def add(self,volume):
        self.volume.append(volume)
    def __repr__(self):
        return f"{self.truck}:{self.volume}"

# %% [markdown]
# **(b) Find the truck with the highest total volume — 8 marks**
#
# After calling your total_volume() function:
#
# Write code (outside the function) to find which truck delivered the largest amount of concrete in total.
#
#
# *   Store the truck ID and its total volume.
# *   Print the result using this exact format:
#
#
# Top truck: T02 delivered 12.0 m3 (Your numbers should match the actual computed values.)

# %% [markdown]
# ** (c) Create a sorted list of truck IDs — 5 marks **
#
# Using the dictionary returned by your function:
#
#
#
# *   Extract all truck IDs (the dictionary keys).
# *   Put them into a list.
# *   Sort the list in ascending alphabetical order.
# *   Print the sorted list.
#
#
# Example format:
#
# Sorted truck IDs: ['T01', 'T02', 'T03']

# %% [markdown]
# **Question 2 - 25 marks**
#
# A small dam monitors the daily water level (in meters) for 14 days. The data is stored in a Python list:
#
# water_levels = [2.1, 2.3, 2.8, 3.0, 3.5, 4.2, 4.8, 5.1, 4.9, 4.0, 3.7, 3.2, 2.9, 2.4]
#
#
# The safe operating range for the dam is:
#
# Below 2.5 m → Too Low (Risk of insufficient water supply)
#
# 2.5 m to 4.5 m → Normal
#
# Above 4.5 m → High (Flood Risk)
#
#
# **TASK 1 - 8 marks**
#
# 1.   Print the water level on Day 1 (index 0)
# 2.   Print the water level on the last day using negative indexing.
# 3.   Print the water levels for days 5 to 8 using a loop with indexing.
# 4.   Print the maximum water level and the day it occurred (use indexing, not built-in functions like .index()).

# %%
water_levels = [2.1, 2.3, 2.8, 3.0, 3.5, 4.2, 4.8, 5.1, 4.9, 4.0, 3.7, 3.2, 2.9, 2.4]
print(" The water level on day 1 is ", water_levels[0])
print(" The water level on the last day is ", water_levels[-1])
print(" The water levels for days 5 to 8 is ", water_levels[4:8])
print(" The maximum water level is ", water_levels[7], " on day number 8")
# Out:
#  The water level on day 1 is  2.1
#  The water level on the last day is  2.4
#  The water levels for days 5 to 8 is  [3.5, 4.2, 4.8, 5.1]
#  The maximum water level is  5.1  on day number 8

# %% [markdown]
# **TASK 2 - 8 marks**
#
# Write a loop that goes through all 14 days and prints the risk category for each day using the rules:
#
# If level < 2.5 → "Too Low"
#
# If 2.5 ≤ level ≤ 4.5 → "Normal"
#
# If level > 4.5 → "High"
#
#
# Your output format should be:
#
# Day 1: 2.1 m → Too Low
#
# Day 2: 2.3 m → Too Low
#
# Day 3: 2.8 m → Normal

# %%
water_levels = [2.1, 2.3, 2.8, 3.0, 3.5, 4.2, 4.8, 5.1, 4.9, 4.0, 3.7, 3.2, 2.9, 2.4]
for value in water_levels:
    if water_levels < 2.5:
        condition = "Too Low"
    elif 2.5 <= water_levels <= 4.5:
        condition = "Normal"
    else:
        condition = "High"
    print("Day 1: ", water_levels[0]", condition)
# Out:
#   Cell In[29], line 9
#     print("Day 1: ", water_levels[0]", condition)
#                                     ^
# SyntaxError: unterminated string literal (detected at line 9)

# %% [markdown]
# **TASK 3 - 6 marks**
#
# Write code that counts how many days fall into:
#
# Too Low
#
# Normal
#
# High
#
# Store the counts in three separate variables and print:
#
# Too Low days: X
#
# Normal days: Y
#
# High days: Z

# %%
water_levels = [2.1, 2.3, 2.8, 3.0, 3.5, 4.2, 4.8, 5.1, 4.9, 4.0, 3.7, 3.2, 2.9, 2.4]
low = 0
normal = 0
high = 0
for water_levels in water_levels:
    if water_levels < 2.5:
        low += 1
    elif 2.5 <= water_levels <= 4.5:
        normal += 1
    else:
        high += 1
    print(low)
    print(normal)
    print(high)
# Out:
# 1
# 0
# 0
# 2
# 0
# 0
# 2
# 1
# 0
# 2
# 2
# 0
# 2
# 3
# 0
# 2
# 4
# 0
# 2
# 4
# 1
# 2
# 4
# 2
# 2
# 4
# 3
# 2
# 5
# 3
# 2
# 6
# 3
# 2
# 7
# 3
# 2
# 8
# 3
# 3
# 8
# 3

# %% [markdown]
# **TASK 4 - 3 marks**
#
# Write an if–else block to check dam safety:
#
# If the number of High days is greater than 3, print:
#
# Warning: Extended High Water Level Period
#
#
# Else if Too Low days are greater than 5, print:
#
# Warning: Prolonged Low Water Level
#
#
# Otherwise, print:
#
# Water Levels Stable

# %% [markdown]
# **Question 3- 25 marks **
#
# A structural inspection system encodes each element as a single string.
# You are given the following structural element code:
#
# element = "COL-04A-RC-3500MM"
#
#
# This code stores:
#
# Characters 0–2 → Element type (e.g., COL = Column)
#
# Characters 4–7 → Element ID
#
# Characters 9–10 → Material type (e.g., RC = Reinforced Concrete)
#
# Characters 12–16 → Height of element (e.g., 3500MM)
#
# **TASK 1 - 10 marks**
#
# Using string indexing, write code to:
#
# 1.   Print the first character of the string
# 2.   Print the last character of the string
# 3.   Print "RC" by using string indexing
# 4.   Print "3500MM" by using string indexing
# 5.   Print how many characters the string has
# 6.   Print the middle character using indexing (Length can be odd or even; use integer division len(element) // 2)

# %%
element = "COL-04A-RC-3500MM"
print(element[0])
print(element[-1])
print(element[8:10])
print(element[-6:])
print(len(element))
print(len(element)/2)
# Out:
# C
# M
# RC
# 3500MM
# 17
# 8.5

# %% [markdown]
# **TASK 2 - 8 marks**
#
# Use string slicing to extract the following:
#
# Element type → "COL"
#
# Element ID → "04A"
#
# Material type → "RC"
#
# Height → "3500MM"
#
# Then print them in this format:
#
# Type: COL
#
# ID: 04A
#
# Material: RC
#
# Height: 3500MM

# %%
element = "COL-04A-RC-3500MM"
print(element.split(3!))
# Out:
#   Cell In[26], line 2
#     print(element.split(3!))
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# **TASK 3 - 4 marks**
#
# Write Python code to:
#
# Create a new string where "RC" is replaced with "STEEL"
#
# *   Convert the entire modified string into lowercase
# *   Print the result
#
#
# Expected output pattern:
#
# col-04a-steel-3500mm

# %% [markdown]
# **TASK 4 - 3 marks**
#
# Reverse the entire string using slicing
#
# Check if the substring "MM" appears in the original string
#
# If yes, print "Unit found"
#
# Otherwise, print "Unit not found"

# %% [markdown]
# **Question 4 - 25 marks**
#
#
# **PART 1 - 8 marks**
#
# You are given several pieces of buggy Python code related to a BridgeSensor system.
# Each snippet is supposed to help civil engineers monitor loads on a bridge.
#
# For each part:
#
# Identify the error(s) in the code.
#
#
# Write the corrected version of the code so that it produces the expected output.

# %%
class BridgeSensor:
    def __init__(self, sensor_id, readings):
        self.sensor_id = sensor_id
        self.readings = readings   # list of float values

s1 = BridgeSensor("S1", [2.1, 2.3, 2.5])
s2 = BridgeSensor("S2", [1.9, 2.0])
s3 = BridgeSensor("S3", [2.8])

sensors = [s1, s2, s3]

# Print: "Sensor S1 latest: 2.5", etc.
for i in range(len(sensors)):
    latest = sensors[i].readings[len(sensors[i].readings)]
    print("Sensor", sensors[i].sensor_id, "latest:", latest)

# Expected output:
# Sensor S1 latest: 2.5
# Sensor S2 latest: 2.0
# Sensor S3 latest: 2.8

# %% [markdown]
# **PART 2 - 9 marks**
#
# The engineer wants to store the maximum allowed load for each sensor as a private attribute.
# They also want a method to check whether the latest reading exceeds the limit.
#
# Fix the class so that:
#
# The overload check works correctly with the private attribute.
#
# The max load can be read from outside the class using a method (for example, a getter).
#
# The code produces exactly the expected output shown above

# %%
class BridgeSensor:
    def __init__(self, sensor_id, readings, max_load):
        self.sensor_id = sensor_id
        self.readings = readings
        self.__max_load = max_load   # private attribute (Do not change it)

    def is_overloaded(self):
        latest = self.readings[-1]
        if latest > self.max_load:
            return True
        else:
            return False

s = BridgeSensor("S1", [2.0, 2.3, 3.1], 3.0)

print("Max load for sensor:", s.__max_load)
print("Overloaded?", s.is_overloaded())

# Expected output:
# Max load for sensor: 3.0
# Overloaded? True

# %% [markdown]
# **PART 3 - 8 marks**
#
# The engineer wants a method that returns both:
#
# the average reading
#
# and a status string "OK" or "OVERLOAD" based on __max_load.
#
#
# Rewrite the average_status method so that:
#
# It has the correct parameter list.
#
# It correctly calculates the average using self.readings.
#
# It returns two values: (avg, status) instead of printing them.

# %%
class BridgeSensor:
    def __init__(self, sensor_id, readings, max_load):
        self.sensor_id = sensor_id
        self.readings = readings
        self.__max_load = max_load

    def average_status(limit):
        total = 0
        for r in self.readings:      # BUG HERE
            total = total + r
        avg = total / len(self.readings)

        if avg <= self.__max_load:
            status = "OK"
        else:
            status = "OVERLOAD"

        print("Average:", avg, "Status:", status)  # BUG: should RETURN

s = BridgeSensor("S2", [2.5, 3.0, 3.5], 3.0)

avg_value, status_text = s.average_status()
print("For sensor", s.sensor_id, "=>", avg_value, status_text)

# Expected output:
# For sensor S2 => 3.0 OK
